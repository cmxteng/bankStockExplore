# %% [markdown]
# # Finance Data Learning Project
#
# Data analysis of stock prices. This project is just meant to practice.
# ____
# This is to focus on bank stocks and see how they progressed throughout the [financial crisis](https://en.wikipedia.org/wiki/Financial_crisis_of_2007%E2%80%9308) all the way to early 2016.

# %% [markdown]
# ## Get the Data
#
# In this section, use pandas to directly read data from Google finance using pandas!
#
#
#
# ### The Imports

# %%
import pandas as pd
import numpy as np
import datetime
# %matplotlib inline

# %% [markdown]
# ## Data
#
# To get data, use pandas datareader. Use stock information for the following banks:
# *  Bank of America
# * CitiGroup
# * Goldman Sachs
# * JPMorgan Chase
# * Morgan Stanley
# * Wells Fargo
#
# ** Get the stock data from Jan 1st 2006 to Jan 1st 2016 for each of these banks.**

# %%
# Could also do this for a Panel Object
df  = pd.read_pickle('all_banks')

# %%
df.head()
# Out:
# Bank Ticker    BAC                                     C                       \
# Stock Info    Open   High    Low  Close    Volume   Open   High    Low  Close
# Date
# 2006-01-03   46.92  47.18  46.15  47.08  16296700  490.0  493.8  481.1  492.9
# 2006-01-04   47.00  47.24  46.45  46.58  17757900  488.6  491.0  483.5  483.8
# 2006-01-05   46.58  46.83  46.32  46.64  14970900  484.4  487.8  484.0  486.2
# 2006-01-06   46.80  46.91  46.35  46.57  12599800  488.8  489.0  482.0  486.2
# 2006-01-09   46.72  46.97  46.36  46.60  15620000  486.0  487.4  483.0  483.9
#
# Bank Ticker           ...     MS                                  WFC         \
# Stock Info    Volume  ...   Open   High    Low  Close   Volume   Open   High
# Date                  ...
# 2006-01-03   1537660  ...  57.17  58.49  56.74  58.31  5377000  31.60  31.98
# 2006-01-04   1871020  ...  58.70  59.28  58.35  58.35  7977800  31.80  31.82
# 2006-01-05   1143160  ...  58.55  58.59  58.02  58.51  5778000  31.50  31.56
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2517 entries, 2006-01-03 to 2015-12-31
# Data columns (total 30 columns):
# (BAC, Open)      2517 non-null float64
# (BAC, High)      2517 non-null float64
# (BAC, Low)       2517 non-null float64
# (BAC, Close)     2517 non-null float64
# (BAC, Volume)    2517 non-null int64
# (C, Open)        2517 non-null float64
# (C, High)        2517 non-null float64
# (C, Low)         2517 non-null float64
# (C, Close)       2517 non-null float64
# (C, Volume)      2517 non-null int64
# (GS, Open)       2517 non-null float64
# (GS, High)       2517 non-null float64
# (GS, Low)        2517 non-null float64
# (GS, Close)      2517 non-null float64
# (GS, Volume)     2517 non-null int64
# (JPM, Open)      2517 non-null float64
# (JPM, High)      2517 non-null float64
# (JPM, Low)       2517 non-null float64
# (JPM, Close)     2517 non-null float64
# (JPM, Volume)    2517 non-null int64
# (MS, Open)       2517 non-null float64
# ...

# %%
df.describe()
# Out:
# Bank Ticker          BAC                                                       \
# Stock Info          Open         High          Low        Close        Volume
# count        2517.000000  2517.000000  2517.000000  2517.000000  2.517000e+03
# mean           22.205217    22.479182    21.894076    22.174617  1.333590e+08
# std            15.308041    15.406193    15.197964    15.304852  1.274974e+08
# min             3.220000     3.510000     2.530000     3.140000  4.836000e+06
# 25%            12.310000    12.450000    12.130000    12.270000  4.845598e+07
# 50%            15.780000    15.970000    15.600000    15.790000  1.015867e+08
# 75%            32.730000    33.600000    31.750000    32.630000  1.752694e+08
# max            55.040000    55.080000    54.820000    54.900000  1.226791e+09
#
# Bank Ticker            C                                                       \
# Stock Info          Open         High          Low        Close        Volume
# ...

# %% [markdown]
# # EDA
#
# Explore the data.
#
# ** Max Close price for each bank's stock throughout the time period**

# %%
df.xs(key='Close',axis=1,level='Stock Info').max()
# Out:
# Bank Ticker
# BAC     54.90
# C      564.10
# GS     247.92
# JPM     70.08
# MS      89.30
# WFC     58.52
# dtype: float64

# %% [markdown]
# ** Create a new empty DataFrame called returns. This dataframe will contain the returns for each bank's stock. returns are typically defined by:**
#
# $$r_t = \frac{p_t - p_{t-1}}{p_{t-1}} = \frac{p_t}{p_{t-1}} - 1$$

# %%
returns = pd.DataFrame()

# %% [markdown]
# ** Use pandas pct_change() method on the Close column to create a column representing this return value. **

# %%
for tick in tickers:
    returns[tick+' Return'] = df[tick]['Close'].pct_change()
returns.head()
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.000951
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005714
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586    0.000000

# %% [markdown]
# ** Create a pairplot using seaborn of the returns dataframe. **
#
# Check the stock stands out

# %%
#returns[1:]
import seaborn as sns
sns.set_style('whitegrid')
sns.pairplot(returns[1:])

# %% [markdown]
# Background on [Citigroup's Stock Crash available here.](https://en.wikipedia.org/wiki/Citigroup#November_2008.2C_Collapse_.26_US_Government_Intervention_.28part_of_the_Global_Financial_Crisis.29)
#
# Plot the enormous crash in value

# %%
# Worst Drop (4 of them on Inauguration day)
returns.idxmin()
# Out:
# BAC Return   2009-01-20
# C Return     2011-05-06
# GS Return    2009-01-20
# JPM Return   2009-01-20
# MS Return    2008-10-09
# WFC Return   2009-01-20
# dtype: datetime64[ns]

# %% [markdown]
# **notice that 4 of the banks share the same day for the worst drop**

# %% [markdown]
# [Citigroup had a stock split.](https://finance.yahoo.com/chart/C#...%3D)

# %%
# Best Single Day Gain
# citigroup stock split in May 2011, but also JPM day after inauguration.
returns.idxmax()
# Out:
# BAC Return   2009-04-09
# C Return     2011-05-09
# GS Return    2008-11-24
# JPM Return   2009-01-21
# MS Return    2008-10-13
# WFC Return   2008-07-16
# dtype: datetime64[ns]

# %% [markdown]
# **noticed that Citigroup's largest drop and biggest gain were very close to one another**

# %% [markdown]
# ** Get standard deviation of the returns to classify the riskiest bank over the entire time period**

# %%
returns.std() # Citigroup riskiest
# Out:
# BAC Return    0.036650
# C Return      0.179969
# GS Return     0.025346
# JPM Return    0.027656
# MS Return     0.037820
# WFC Return    0.030233
# dtype: float64

# %%
returns.loc['2015-01-01':'2015-12-31'].std()  # Very similar risk profiles, but Morgan Stanley or BofA
# Out:
# BAC Return    0.016163
# C Return      0.015289
# GS Return     0.014046
# JPM Return    0.014017
# MS Return     0.016249
# WFC Return    0.012591
# dtype: float64

# %% [markdown]
# ** Create a distplot using seaborn of the 2015 returns for Morgan Stanley **

# %%
sns.distplot(returns.loc['2015-01-01':'2015-12-31']['MS Return'],color='green',bins=100)

# %% [markdown]
# ** Create a distplot using seaborn of the 2008 returns for CitiGroup **

# %%
sns.distplot(returns.loc['2008-01-01':'2008-12-31']['C Return'],color='red',bins=100)

# %% [markdown]
# ____
# # More Visualization
#
#
# ### Imports

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# Optional Plotly Method Imports
import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
for tick in tickers:
    df[tick]['Close'].plot(figsize=(12,4),label=tick)
plt.legend()

# %%
df.xs(key='Close',axis=1,level='Stock Info').plot()

# %%
# plotly
df.xs(key='Close',axis=1,level='Stock Info').iplot()
# Out:
# <div>
#
#
#             <div id="c4dc9f19-7e8d-46dd-8bf7-b5354d0d6b26" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c4dc9f19-7e8d-46dd-8bf7-b5354d0d6b26")) {
#                     Plotly.newPlot(
#                         'c4dc9f19-7e8d-46dd-8bf7-b5354d0d6b26',
# ...

# %% [markdown]
# ## Moving Averages
#
# Analyze the moving averages for these stocks in the year 2008.
#
# ** Plot the rolling 30 day average against the Close Price for Bank Of America's stock for the year 2008**

# %%
plt.figure(figsize=(12,6))
BAC['Close'].loc['2008-01-01':'2009-01-01'].rolling(window=30).mean().plot(label='30 Day Avg')
BAC['Close'].loc['2008-01-01':'2009-01-01'].plot(label='BAC CLOSE')
plt.legend()

# %% [markdown]
# ** Create a heatmap of the correlation between the stocks Close Price.**

# %%
sns.heatmap(df.xs(key='Close',axis=1,level='Stock Info').corr(),annot=True)

# %%
sns.clustermap(df.xs(key='Close',axis=1,level='Stock Info').corr(),annot=True)

# %%
close_corr = df.xs(key='Close',axis=1,level='Stock Info').corr()
close_corr.iplot(kind='heatmap',colorscale='rdylbu')
# Out:
# <div>
#
#
#             <div id="5ed3b51c-2826-4e44-b217-a4dc5b5fd748" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5ed3b51c-2826-4e44-b217-a4dc5b5fd748")) {
#                     Plotly.newPlot(
#                         '5ed3b51c-2826-4e44-b217-a4dc5b5fd748',
# ...

# %% [markdown]
# # Part 2 (Optional)
#
# In this second part of the project, cufflinks library is use to create some Technical Analysis plots.

# %% [markdown]
# ** Use .iplot(kind='candle) to create a candle plot of Bank of America's stock from Jan 1st 2015 to Jan 1st 2016.**

# %%
BAC[['Open', 'High', 'Low', 'Close']].loc['2015-01-01':'2016-01-01'].iplot(kind='candle')
# Out:
# <div>
#
#
#             <div id="1bc66d3d-75cb-4c29-8c7f-59262bc240fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("1bc66d3d-75cb-4c29-8c7f-59262bc240fd")) {
#                     Plotly.newPlot(
#                         '1bc66d3d-75cb-4c29-8c7f-59262bc240fd',
# ...

# %% [markdown]
# ** Use .ta_plot(study='sma') to create a Simple Moving Averages plot of Morgan Stanley for the year 2015.**

# %%
MS['Close'].loc['2015-01-01':'2016-01-01'].ta_plot(study='sma',periods=[13,21,55],title='Simple Moving Averages')
# Out:
# <div>
#
#
#             <div id="acdbbcb3-6419-4402-b247-99d3949fd51b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("acdbbcb3-6419-4402-b247-99d3949fd51b")) {
#                     Plotly.newPlot(
#                         'acdbbcb3-6419-4402-b247-99d3949fd51b',
# ...

# %% [markdown]
# **Use .ta_plot(study='boll') to create a Bollinger Band Plot for Bank of America for the year 2015.**

# %%
BAC['Close'].loc['2015-01-01':'2016-01-01'].ta_plot(study='boll')
# Out:
# <div>
#
#
#             <div id="e42f8f9a-3efe-4088-b9a3-9d7a2e6a37d1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e42f8f9a-3efe-4088-b9a3-9d7a2e6a37d1")) {
#                     Plotly.newPlot(
#                         'e42f8f9a-3efe-4088-b9a3-9d7a2e6a37d1',
# ...

# %% [markdown]
# # The End!
